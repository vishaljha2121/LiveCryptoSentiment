# %%
import pandas as pd

# %%
df = pd.read_csv("../Scripts/solana_twitter_data.csv")
df
# Out:
#     final_score                                              tweet      time  \
# 0      0.194558  .@SergeyNazarov on the @solana podcast, based ...  03:44:38
# 1      0.000000  @TheCryptoDog @aeyakovenko Well said man, this...  04:04:22
# 2      0.000000                        @i_solana wish that were me  04:07:44
# 3      0.000000  Solana hive rissseeeee up 🔥🔥🔥 #NS10v10  https:...  04:19:11
# 4      0.019955  my twitter presence is very solana, my authent...  04:19:37
# 5      0.187075  2020 was a difficult and challenging year for ...  04:34:41
# 6      0.000000  @ChainLinkGod @solana @SergeyNazarov Heh, you ...  04:37:10
# 7      1.000000  Episode #33 of The Solana Podcast featuring th...  04:45:10
# 8      0.000000  @solana @Smart_Contract @chainlink @SergeyNaza...  04:48:53
# 9      0.000000  @ChainLinkGod @SergeyNazarov @solana Sergey’s ...  05:08:40
# 10     0.000000  @solana @Smart_Contract @chainlink @SergeyNaza...  05:13:09
# ...

# %%
len(df)
# Out:
# 16
